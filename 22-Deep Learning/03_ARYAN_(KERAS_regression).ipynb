# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/cancer_classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %%
sns.countplot(x='benign_0__mal_1',data=df)
# Out:
# <Axes: xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
X = df.drop('benign_0__mal_1',axis = 1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# #NEXT VIDEO : prevent overfitting etc

# %%
# create the model

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense,Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()
model.add(Dense(30,activation='relu'))
model.add(Dense(15,activation='relu'))

# BINARY CLASSIFICATION PROBLEM
#hence sigmoid activation function
model.add(Dense(1,activation='sigmoid'))
model.compile(loss = 'binary_crossentropy' , optimizer = 'adam')

# %%
# MODEL TRAINING
model.fit(x=X_train, y=y_train, epochs = 600, validation_data = (X_test,y_test))
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 15ms/step - loss: 0.6905 - val_loss: 0.6617
# Epoch 2/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6335 - val_loss: 0.6007
# Epoch 3/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5701 - val_loss: 0.5399
# Epoch 4/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5144 - val_loss: 0.4890
# Epoch 5/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4659 - val_loss: 0.4415
# Epoch 6/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4220 - val_loss: 0.3968
# Epoch 7/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3774 - val_loss: 0.3541
# Epoch 8/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3418 - val_loss: 0.3172
# Epoch 9/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3074 - val_loss: 0.2861
# Epoch 10/600
# ...

# %%
# plotting both training and validation loss
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
# this is a indication that we are overfitting our training data

# %% [markdown]
# First way to stop overfitting of data is EARLY STOPPING method

# %%
model = Sequential()
model.add(Dense(30,activation='relu'))
model.add(Dense(15,activation='relu'))

# BINARY CLASSIFICATION PROBLEM
#hence sigmoid activation function
model.add(Dense(1,activation='sigmoid'))
model.compile(loss = 'binary_crossentropy' , optimizer = 'adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience = 25)

# %%
# MODEL TRAINING
model.fit(x=X_train, y=y_train, epochs = 600, validation_data = (X_test,y_test),
          callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 13ms/step - loss: 0.6513 - val_loss: 0.6298
# Epoch 2/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6133 - val_loss: 0.5890
# Epoch 3/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5697 - val_loss: 0.5404
# Epoch 4/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5181 - val_loss: 0.4856
# Epoch 5/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.4634 - val_loss: 0.4265
# Epoch 6/600
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4104 - val_loss: 0.3742
# Epoch 7/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3637 - val_loss: 0.3307
# Epoch 8/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3301 - val_loss: 0.2975
# Epoch 9/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3071 - val_loss: 0.2744
# Epoch 10/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <Axes: >

# %% [markdown]
# ANOTHER WAY TO STOP OVERFITTING IS ADDING DROPOUT LAYERS plus using EARLY STOPPING

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(30,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(15,activation='relu'))
model.add(Dropout(0.5))

# BINARY CLASSIFICATION PROBLEM
#hence sigmoid activation function
model.add(Dense(1,activation='sigmoid'))
model.compile(loss = 'binary_crossentropy' , optimizer = 'adam')

# %%
# MODEL TRAINING
model.fit(x=X_train, y=y_train, epochs = 600, validation_data = (X_test,y_test),
          callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 1s 14ms/step - loss: 0.6705 - val_loss: 0.6732
# Epoch 2/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6808 - val_loss: 0.6606
# Epoch 3/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6513 - val_loss: 0.6423
# Epoch 4/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6451 - val_loss: 0.6205
# Epoch 5/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6263 - val_loss: 0.5989
# Epoch 6/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6156 - val_loss: 0.5756
# Epoch 7/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5854 - val_loss: 0.5507
# Epoch 8/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5548 - val_loss: 0.5238
# Epoch 9/600
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5330 - val_loss: 0.4882
# Epoch 10/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.plot()
# Out:
# <Axes: >

# %%
#EVALUATE MODEL CLASSES

# %%
predictions = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        55
#            1       0.99      0.97      0.98        88
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[54  1]
#  [ 3 85]]
