# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
#lets start with CONDITIONAL SELECTION

# %%
booldf = df>0

# %%
booldf
# Out:
#        W      X      Y      Z
# A   True   True   True   True
# B   True  False  False   True
# C  False   True   True  False
# D   True  False  False   True
# E   True   True   True   True

# %%
df[booldf]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118       NaN       NaN  0.605965
# C       NaN  0.740122  0.528813       NaN
# D  0.188695       NaN       NaN  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['W'] > 0
# Out:
# A     True
# B     True
# C    False
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[df['W'] > 0]
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df[df['W']> 0][['X','Y']]
# Out:
#           X         Y
# A  0.628133  0.907969
# B -0.319318 -0.848077
# D -0.758872 -0.933237
# E  1.978757  2.605967

# %%
#two conditions

# %%
df[(df['W'] > 0) & (df['Y'] > 1)]
# Out:
#           W         X         Y         Z
# E  0.190794  1.978757  2.605967  0.683509

# %%
df
# Out:
#   index         W         X         Y         Z STATES
# 0     A  0.302665  1.693723 -1.706086 -1.159119     MH
# 1     B -0.134841  0.390528  0.166905  0.184502     CH
# 2     C  0.807706  0.072960  0.638787  0.329646     PJ
# 3     D -0.497104 -0.754070 -0.943406  0.484752     JK
# 4     E -0.116773  1.901755  0.238127  1.996652     KL

# %%
df
# Out:
#   index         W         X         Y         Z STATES
# 0     A  0.302665  1.693723 -1.706086 -1.159119     MH
# 1     B -0.134841  0.390528  0.166905  0.184502     CH
# 2     C  0.807706  0.072960  0.638787  0.329646     PJ
# 3     D -0.497104 -0.754070 -0.943406  0.484752     JK
# 4     E -0.116773  1.901755  0.238127  1.996652     KL

# %%
newind = "MH CH PJ JK KL".split()

# %%
newind
# Out:
# ['MH', 'CH', 'PJ', 'JK', 'KL']

# %%
df["STATES"] = newind

# %%
df
# Out:
#   index         W         X         Y         Z STATES
# 0     A  0.302665  1.693723 -1.706086 -1.159119     MH
# 1     B -0.134841  0.390528  0.166905  0.184502     CH
# 2     C  0.807706  0.072960  0.638787  0.329646     PJ
# 3     D -0.497104 -0.754070 -0.943406  0.484752     JK
# 4     E -0.116773  1.901755  0.238127  1.996652     KL

# %%
df.set_index("STATES")
# Out:
#        index         W         X         Y         Z
# STATES
# MH         A  0.302665  1.693723 -1.706086 -1.159119
# CH         B -0.134841  0.390528  0.166905  0.184502
# PJ         C  0.807706  0.072960  0.638787  0.329646
# JK         D -0.497104 -0.754070 -0.943406  0.484752
# KL         E -0.116773  1.901755  0.238127  1.996652

# %%
df.drop("index",axis=1)
# Out:
#           W         X         Y         Z STATES
# 0  0.302665  1.693723 -1.706086 -1.159119     MH
# 1 -0.134841  0.390528  0.166905  0.184502     CH
# 2  0.807706  0.072960  0.638787  0.329646     PJ
# 3 -0.497104 -0.754070 -0.943406  0.484752     JK
# 4 -0.116773  1.901755  0.238127  1.996652     KL

# %%
df
# Out:
#   index         W         X         Y         Z STATES
# 0     A  0.302665  1.693723 -1.706086 -1.159119     MH
# 1     B -0.134841  0.390528  0.166905  0.184502     CH
# 2     C  0.807706  0.072960  0.638787  0.329646     PJ
# 3     D -0.497104 -0.754070 -0.943406  0.484752     JK
# 4     E -0.116773  1.901755  0.238127  1.996652     KL
